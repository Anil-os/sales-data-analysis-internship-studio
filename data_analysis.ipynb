# %% [markdown]
# # Sales Data Analysis and Reporting for a Retail Chain
#
# **Submitted By:** Anil Kumar H
# **Domain:** Data Analytics
# **Platform:** Internship Studio

# %% [markdown]
# ## Project Objective
# To analyze retail sales data and extract meaningful insights using Python.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print('Libraries imported successfully')

# %% [markdown]
# ## Data Cleaning and Preparation
# - Removed duplicate values
# - Handled missing values
# - Converted date columns
# - Created calculated fields like total sales

# %% [markdown]
# ## Exploratory Data Analysis
# - Sales trend analysis
# - Top-selling products
# - Region-wise sales performance

# %% [markdown]
# ## Conclusion
# This project demonstrates how data analytics helps businesses make data-driven decisions.
